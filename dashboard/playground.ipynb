# %% [markdown]
# ### Explore visualisation options

# %%
import pandas as pd
import altair as alt
import streamlit
from datetime import timedelta

# %%
data = pd.read_csv('mock_data.csv')
data['recording_taken'] = pd.to_datetime(data['recording_taken'])
data.head()
# Out:
#    plant_id  soil_moisture  temperature     recording_taken
# 0         0      25.412010    12.901289 2023-12-19 11:21:43
# 1         0      24.631308    13.597571 2023-12-19 11:22:43
# 2         0      28.679350    12.853489 2023-12-19 11:23:43
# 3         0      27.300303    13.077382 2023-12-19 11:24:43
# 4         0      25.699151    13.435078 2023-12-19 11:25:43

# %%
# data.set_index('recording_taken', inplace=True)
first_recording = data.iloc[-1]['recording_taken'] - timedelta(hours=23, minutes=59)

data[first_recording:'2023-12-19 11:25:43']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 4
#       1 # data.set_index('recording_taken', inplace=True)
#       2 first_recording = data.iloc[-1]['recording_taken'] - timedelta(hours=23, minutes=59)
# ----> 4 data[first_recording:'2023-12-19 11:25:43']
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:3876, in DataFrame.__getitem__(self, key)
#    3874 # Do we have a slicer (on rows)?
#    3875 if isinstance(key, slice):
# -> 3876     return self._getitem_slice(key)
#    3878 # Do we have a (boolean) DataFrame?
#    3879 if isinstance(key, DataFrame):
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4284, in NDFrame._getitem_slice(self, key)
#    4279 """
#    4280 __getitem__ for the case where the key is a slice object.
#    4281 """
#    4282 # _convert_slice_indexer to determine if this slice is positional
#    4283 #  or label based, and if the latter, convert to positional
# -> 4284 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4285 if isinstance(slobj, np.ndarray):
#    4286     # reachable with DatetimeIndex
#    4287     indexer = lib.maybe_indices_to_slice(
#    4288         slobj.astype(np.intp, copy=False), len(self)
#    4289     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:4247, in Index._convert_slice_indexer(self, key, kind)
#    4244     return key
#    4245 elif self.dtype.kind in "iu":
#    4246     # Note: these checks are redundant if we know is_index_slice
# -> 4247     self._validate_indexer("slice", key.start, "getitem")
#    4248     self._validate_indexer("slice", key.stop, "getitem")
#    4249     self._validate_indexer("slice", key.step, "getitem")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:6637, in Index._validate_indexer(self, form, key, kind)
#    6632 """
#    6633 If we are positional indexer, validate that we have appropriate
#    6634 typed bounds must be an integer.
#    6635 """
#    6636 if not lib.is_int_or_none(key):
# -> 6637     self._raise_invalid_indexer(form, key)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:4306, in Index._raise_invalid_indexer(self, form, key, reraise)
#    4304 if reraise is not lib.no_default:
#    4305     raise TypeError(msg) from reraise
# -> 4306 raise TypeError(msg)
#
# TypeError: cannot do slice indexing on RangeIndex with these indexers [2023-12-19 11:21:43] of type Timestamp

# %%
RESAMPLE_RATE = '10T'
LINE_WIDTH = 2
FIG_WIDTH = 800
FIG_HEIGHT = FIG_WIDTH / 8

# %%
resampled_data = data.resample(RESAMPLE_RATE, on='recording_taken').mean().reset_index()
y_min = resampled_data['soil_moisture'].min()
y_max = resampled_data['soil_moisture'].max()

alt.Chart(resampled_data).mark_line(
    interpolate='cardinal',
    tension=0.8,
    strokeWidth=LINE_WIDTH,
).encode(
    x=alt.X('recording_taken:T', axis=alt.Axis(title='Time', format='%H:%M')),
    y=alt.Y('soil_moisture:Q', scale=alt.Scale(domain=[y_min - 2, y_max + 2]), axis=alt.Axis(title='Soil Moisture (%)'))
).properties(
    width=FIG_WIDTH,
    height=FIG_HEIGHT,
    title=alt.Title(
        "Unveiling trends",
        subtitle=["A timeline of plant health"],
        anchor='start',
        orient='bottom',
        offset=20)
).configure_axis(
    # labelFontSize=TICK_LABEL_FONT_SIZE,
    # titleFontSize=AXIS_LABEL_FONT_SIZE,
).configure_title(
    # fontSize=TITLE_FONT_SIZE,
)
# Out:
# alt.Chart(...)

# %%
resampled_data = data.resample(RESAMPLE_RATE, on='recording_taken').mean().reset_index()
y_min = resampled_data['temperature'].min()
y_max = resampled_data['temperature'].max()

alt.Chart(resampled_data).mark_line(
    interpolate='cardinal',
    tension=0.8,
    strokeWidth=LINE_WIDTH,
).encode(
    x=alt.X('recording_taken:T', axis=alt.Axis(title='Time', format='%H:%M')),
    y=alt.Y('temperature:Q', scale=alt.Scale(domain=[y_min - 2, y_max+ 2]), axis=alt.Axis(title='Temperature (°C)'))
).properties(
    width=FIG_WIDTH,
    height=FIG_HEIGHT,
    title=alt.Title(
        "Unveiling trends",
        subtitle=["A timeline of plant health"],
        anchor='start',
        orient='bottom',
        offset=20)
).configure_axis(
    # labelFontSize=TICK_LABEL_FONT_SIZE,
    # titleFontSize=AXIS_LABEL_FONT_SIZE,
).configure_title(
    # fontSize=TITLE_FONT_SIZE,
)
# Out:
# alt.Chart(...)
